# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(178675309)

# %%
x_rand = np.random.uniform(low=0.000, high=750.000, size=125342)
y_rand = np.random.uniform(low=0.000, high=750.000, size=125342)
z_rand = np.random.uniform(low=0.000, high=750.000, size=125342)

# %%
x_rand
# Out:
# array([ 19.57192124,  79.80736951, 667.54912992, ..., 695.77392643,
#        225.21013614,  48.97555758])

# %%
data_rand = np.transpose(np.array([x_rand, y_rand, z_rand]))

# %%
data_rand
# Out:
# array([[ 19.57192124, 140.35246738, 723.83530322],
#        [ 79.80736951, 171.69542533, 692.35430593],
#        [667.54912992, 159.18558256, 188.3130663 ],
#        ...,
#        [695.77392643, 170.13170234, 462.09719425],
#        [225.21013614, 329.84151529,  10.01518122],
#        [ 48.97555758,  56.67780298, 238.58993848]])

# %%
# 2D slice

# %%
z_max = 70
xy_slice = data_rand[z_rand < z_max] # select rows where z < z_max

# %%
len(xy_slice)
# Out:
# 11611

# %%
plt.plot(xy_slice[:,0],xy_slice[:,1],',')
plt.xlabel("x (Mpc/h)")
plt.ylabel("y (Mpc/h)")
plt.title("Random Catalog")
# Out:
# Text(0.5, 1.0, 'Random Catalog')

# %%
# change fig size to square
