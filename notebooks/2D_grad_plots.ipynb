# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
from matplotlib.patches import Ellipse

sys.path.insert(0, '/home/aew492/CFE_gradients/code')
import load_tools
from generate_mock_list import MockSet
import globals
globals.initialize_vals()
data_dir = globals.data_dir

# %%
def plot_2d_dist(grads_rec, grad_exp, figsize=(6,6), xlim=(None,None), ylim=(None,None), leg_loc=2):
    
    # medians and standard deviation
    median_rec = np.median(grads_rec, axis=0)
    std_rec = np.std(grads_rec, axis=0)
    
    fig, ax = plt.subplots(figsize=figsize)

    # plot individual realizations
    ax.plot(grads_rec[:,0], grads_rec[:,1], marker='.', color='k', alpha=0.8, markersize=2, ls='None')
    # input gradient arrow
    ax.arrow(0,0,grad_exp[0], grad_exp[1], color='blue', alpha=0.8, length_includes_head=True,
             width=0.00001, head_width=0.00015,label='input',zorder=100)

    # ellipse: spread of recovered amplitudes, centered at the median recovered gradient
    for k in range(1,4):
        ellipse1 = Ellipse(xy=(median_rec[0], median_rec[1]), width=k*2*std_rec[0], height=k*2*std_rec[1],
                           color='k', fill=True, alpha=0.2/k)
        ax.add_patch(ellipse1)
    
    # median recovered
    ax.scatter(median_rec[0], median_rec[1], color='white', alpha=0.8, lw=2, marker='x', s=80,
               zorder=100, label='median recovered')
    
    ax.axvline(0, color='k', lw=0.5, alpha=0.3)
    ax.axhline(0, color='k', lw=0.5, alpha=0.3)
    ax.set_aspect('equal')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_xlabel(r'$a_x / a_0$')
    ax.set_ylabel(r'$a_y / a_0$')
    ax.set_title('Recovered gradient amplitudes')
    ax.legend(loc=leg_loc)
    fig.tight_layout()

# %% [markdown]
# ## 2D gradient: $\theta_\mathrm{input} = 30^\circ$; n = 2e-4

# %% [markdown]
# ### CFE

# %% [markdown]
# #### L500, m=0.5

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.5
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m05 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
amps_dict_L500_m05.keys()
# Out:
# dict_keys(['amps', 'grads_rec', 'grads_exp', 'res'])

# %%
plot_2d_dist(amps_dict_L500_m05['grads_rec'], amps_dict_L500_m05['grads_exp'][0])

# %% [markdown]
# #### L500, m=0.75

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.75
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m075 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m075['grads_rec'], amps_dict_L500_m075['grads_exp'][0])

# %% [markdown]
# #### L500, m=1

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 1
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m1 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m1['grads_rec'], amps_dict_L500_m1['grads_exp'][0])

# %% [markdown]
# #### L500, m=0.25

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.25
nmocks = 500

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m025 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m025['grads_rec'], amps_dict_L500_m025['grads_exp'][0])

# %% [markdown]
# #### L500, m=0.375

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.375
nmocks = 500

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m0375 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m025['grads_rec'], amps_dict_L500_m025['grads_exp'][0])

# %% [markdown]
# #### L750, m=0.5

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.5
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m05 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m05['grads_rec'], amps_dict_L750_m05['grads_exp'][0])

# %% [markdown]
# #### L750, m=0.75

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.75
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m075 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m075['grads_rec'], amps_dict_L750_m075['grads_exp'][0])

# %% [markdown]
# #### L750, m=1

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 1
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m1 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m1['grads_rec'], amps_dict_L750_m1['grads_exp'][0])

# %% [markdown]
# #### L750, m=0.375

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.375
nmocks = 150

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m0375 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m0375['grads_rec'], amps_dict_L750_m0375['grads_exp'][0])

# %% [markdown]
# #### L750, m=0.563

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.563
nmocks = 150

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m0563 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m0563['grads_rec'], amps_dict_L750_m0563['grads_exp'][0])

# %% [markdown]
# #### L1000, m=0.5

# %%
L = 1000
n = '2e-4'
grad_dim = 2
m = 0.5
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L1000_m05 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L1000_m05['grads_rec'], amps_dict_L1000_m05['grads_exp'][0])

# %% [markdown]
# #### L1000, m=0.75

# %%
L = 1000
n = '2e-4'
grad_dim = 2
m = 0.75
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L1000_m075 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L1000_m075['grads_rec'], amps_dict_L1000_m075['grads_exp'][0])

# %% [markdown]
# #### L1000, m=1

# %%
L = 1000
n = '2e-4'
grad_dim = 2
m = 1
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L1000_m1 = load_tools.check_grad_amps(mockset, method='suave', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L1000_m1['grads_rec'], amps_dict_L1000_m1['grads_exp'][0])

# %% [markdown]
# ### patches

# %% [markdown]
# #### L500, m=0.5

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.5
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m05_p = load_tools.check_grad_amps(mockset, method='patches', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m05_p['grads_rec'], amps_dict_L500_m05_p['grads_exp'][0])

# %% [markdown]
# #### L500, m=0.75

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 0.75
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m075_p = load_tools.check_grad_amps(mockset, method='patches', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m075_p['grads_rec'], amps_dict_L500_m075_p['grads_exp'][0])

# %% [markdown]
# #### L500, m=1

# %%
L = 500
n = '2e-4'
grad_dim = 2
m = 1
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L500_m1_p = load_tools.check_grad_amps(mockset, method='patches', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L500_m1_p['grads_rec'], amps_dict_L500_m1_p['grads_exp'][0], xlim=(-.005,.005), ylim=(-.005,.005))

# %% [markdown]
# #### L750, m=0.5

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.5
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m05_p = load_tools.check_grad_amps(mockset, method='patches', npatches=8, plot=False, return_amps=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-cb3cd5cbe145> in <module>
#       7 mockset = MockSet(L, n, rlzs=nmocks)
#       8 mockset.add_gradient(grad_dim, m, b=0.5)
# ----> 9 amps_dict_L750_m05_p = load_tools.check_grad_amps(mockset, method='patches', npatches=8, plot=False, return_amps=True)
#
# ~/CFE_gradients/code/load_tools.py in check_grad_amps(mockset, method, bins, alpha, title, plot, return_amps, basis, npatches)
#      40         amps = load_suave_amps(mockset, basis=basis)
#      41     elif method=='patches':
# ---> 42         amps = load_patch_amps(mockset, npatches=npatches)
#      43     else:
#      44         assert False, "'method' must be either 'suave' or 'patches"
#
# ~/CFE_gradients/code/load_tools.py in load_patch_amps(mockset, npatches)
#      24     amps = np.empty((mockset.nmocks,4))
# ...

# %%
plot_2d_dist(amps_dict_L750_m05_p['grads_rec'], amps_dict_L750_m05_p['grads_exp'][0], xlim=(-.005,.005), ylim=(-.005,.005))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-990ab6a0eaee> in <module>
# ----> 1 plot_2d_dist(amps_dict_L750_m05_p['grads_rec'], amps_dict_L750_m05_p['grads_exp'][0], xlim=(-.005,.005), ylim=(-.005,.005))
#
# NameError: name 'plot_2d_dist' is not defined

# %% [markdown]
# #### L750, m=0.75

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 0.75
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m075_p = load_tools.check_grad_amps(mockset, method='patches', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m075_p['grads_rec'], amps_dict_L750_m075_p['grads_exp'][0], xlim=(-.005,.005), ylim=(-.005,.005))

# %% [markdown]
# #### L750, m=1

# %%
L = 750
n = '2e-4'
grad_dim = 2
m = 1
nmocks = 1000

mockset = MockSet(L, n, rlzs=nmocks)
mockset.add_gradient(grad_dim, m, b=0.5)
amps_dict_L750_m1_p = load_tools.check_grad_amps(mockset, method='patches', plot=False, return_amps=True)

# %%
plot_2d_dist(amps_dict_L750_m1_p['grads_rec'], amps_dict_L750_m1_p['grads_exp'][0], xlim=(-.005,.005), ylim=(-.005,.005))

# %% [markdown]
# #### L1000, m=0.5

# %% [markdown]
# #### L1000, m=0.75

# %% [markdown]
# #### L1000, m=1

# %% [markdown]
# # grid of 2D recovered distributions

# %% [markdown]
# ### CFE

# %%
# boxsizes and m values
Ls = [500, 750, 1000]
ms = np.array([[0.25, 0.375, 0.5],
      [0.375, 0.563, 0.75],
    [0.5, 0.75, 1.0]])

# %%
ms.shape
# Out:
# (3, 3)

# %%
# input gradients
input_grads = np.array([[amps_dict_L500_m025['grads_exp'][0],
                         amps_dict_L500_m0375['grads_exp'][0],
                         amps_dict_L500_m05['grads_exp'][0]],
                        [amps_dict_L750_m0375['grads_exp'][0],
                         amps_dict_L750_m0563['grads_exp'][0],
                         amps_dict_L750_m075['grads_exp'][0]],
                        [amps_dict_L1000_m05['grads_exp'][0],
                         amps_dict_L1000_m075['grads_exp'][0],
                         amps_dict_L1000_m1['grads_exp'][0]]
                       ])
input_grads.shape
# Out:
# (3, 3, 3)

# %%
fig, ax = plt.subplots(figsize=(8,6))

leg_loc = 2
cs = ['r', 'g', 'b']

for i, L_set in enumerate(input_grads):
    for j, grad_exp in enumerate(L_set):
        ax.arrow(0,0,grad_exp[0], grad_exp[1], color=cs[i], alpha=0.4, length_includes_head=True,
                 width=0.00001, head_width=0.00015, label=f'L{Ls[i]}, m={ms[j]}')

ax.axvline(0, color='k', lw=0.5, alpha=0.3)
ax.axhline(0, color='k', lw=0.5, alpha=0.3)
ax.set_aspect('equal')
# ax.set_xlim(xlim)
# ax.set_ylim(ylim)
ax.set_xlabel(r'$a_x / a_0$')
ax.set_ylabel(r'$a_y / a_0$')
ax.set_title('Input gradient vectors')
ax.legend(loc=leg_loc)
fig.tight_layout()

# %%
# recovered gradients
nmocks = 150
recovered_grads = np.array([[amps_dict_L500_m025['grads_rec'][:nmocks],
                             amps_dict_L500_m0375['grads_rec'][:nmocks],
                             amps_dict_L500_m05['grads_rec'][:nmocks]],
                            [amps_dict_L750_m0375['grads_rec'][:nmocks],
                             amps_dict_L750_m0563['grads_rec'][:nmocks],
                             amps_dict_L750_m075['grads_rec'][:nmocks]],
                            [amps_dict_L1000_m05['grads_rec'][:nmocks],
                             amps_dict_L1000_m075['grads_rec'][:nmocks],
                             amps_dict_L1000_m1['grads_rec'][:nmocks]],
                           ])
recovered_grads.shape
# Out:
# (3, 3, 150, 3)

# %%
# medians and standard deviation of recovered grads
medians_rec = np.empty((recovered_grads.shape[0], recovered_grads.shape[1], recovered_grads.shape[-1]))
stds_rec = np.empty(medians_rec.shape)
for i, boxsize_set in enumerate(recovered_grads):
    for j, grads_rec in enumerate(boxsize_set):
        medians_rec[i,j] = np.median(grads_rec, axis=0)
        stds_rec[i,j] = np.std(grads_rec, axis=0)

# %%
fig, axs = plt.subplots(3, 3, figsize=(20,16))

leg_loc = 2

for i, row in enumerate(axs):
    for j, ax in enumerate(row):
        
        # # compute axis limits (we want the ratio to the input gradient to be the same for all)
        # xlim = (-1*input_grads[i,j,0], 3*input_grads[i,j,0])
        # ylim = (-1.5*input_grads[i,j,1], 3*input_grads[i,j,1])
        
        # compute axis limits (we want the "physical" a/a0 to be the same for each boxsize)
        # xlim = (-1.2/Ls[i]+input_grads[i,j,0], 1.2/Ls[i]+input_grads[i,j,0])
        # ylim = (-1/Ls[i]+input_grads[i,j,1], 1/Ls[i]+input_grads[i,j,1])
        
        xlim = (-.0006, .0024)
        ylim = (-.0006, .0018)
        
        # plot individual realizations
        ax.plot(recovered_grads[i,j,:,0], recovered_grads[i,j,:,1], marker=',', color='k', alpha=0.8,
                markersize=2, ls='None')
        
        # input gradient arrow
        ax.arrow(0, 0, input_grads[i,j,0], input_grads[i,j,1], color='blue', alpha=0.8,
                 length_includes_head=True, width=0.00001, head_width=0.00015,label='input', zorder=100)
        
        # ellipse: spread of recovered amplitudes, centered at the median recovered gradient
        for k in range(1,4):
            ellipse1 = Ellipse(xy=(medians_rec[i,j,0], medians_rec[i,j,1]), width=k*2*stds_rec[i,j,0],
                               height=k*2*stds_rec[i,j,1], color='k', fill=True, alpha=0.2/k)
            ax.add_patch(ellipse1)
        
        # median recovered
        ax.scatter(medians_rec[i,j,0], medians_rec[i,j,1], color='white', alpha=0.8,
                   lw=2, marker='x', s=80, zorder=101, label='median recovered')
        
        ax.set_title(f'L{Ls[i]}, m={ms[j]}')
        ax.axvline(0, color='k', lw=0.5, alpha=0.3)
        ax.axhline(0, color='k', lw=0.5, alpha=0.3)
        ax.set_aspect('equal')
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        ax.set_xlabel(r'$a_x / a_0$')
        ax.set_ylabel(r'$a_y / a_0$')
        ax.legend(loc=leg_loc)

fig.tight_layout()

# %%
# trio of mocks with the same input vector
recovered_grads_trio = np.array([recovered_grads[i,i,:,:] for i in range(3)])
medians_rec_trio = np.array([medians_rec[i,i,:] for i in range(3)])
stds_rec_trio = np.array([stds_rec[i,i,:] for i in range(3)])
